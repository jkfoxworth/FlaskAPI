# %%
import json
f = r"/home/eric/PycharmProjects/FlaskAPI/scripts/document.json"
fp = open(f, "r")
sample = fp.read()
fp.close()

# %%
sample = json.loads(sample)

# %%
sample['profile']
# Out:
# {'APP_ID_KEY': 'cap-frontend.profile.id.generator.appId',
#  'CONFIG_SECRETE_KEY': 'cap-frontend.profile.id.generator.configSecret',
#  'authToken': 'eQ7g',
#  'authType': 'CAP',
#  'canSendFreeInMail': False,
#  'canSendMessage': True,
#  'certifications': [{'authority': 'Amazon Web Services',
#    'companyLogo': '/AAEAAQAAAAAAAAxoAAAAJGNlYmE5NDBiLTBkODMtNDc0My04Nzc4LWE3ZmYwN2Y5ODZjMA.png',
#    'i18nEndDate': 'December 2016',
#    'i18nStartDate': 'December 2014',
#    'licenseNumber': 'AWS-ASA-4875',
#    'name': 'Solutions Architect Associate Level'},
#   {'authority': 'Amazon Web Services',
#    'companyLogo': '/AAEAAQAAAAAAAAxoAAAAJGNlYmE5NDBiLTBkODMtNDc0My04Nzc4LWE3ZmYwN2Y5ODZjMA.png',
#    'i18nEndDate': 'June 2017',
#    'i18nStartDate': 'June 2015',
#    'licenseNumber': 'AWS-ASOA-1358',
#    'name': 'AWS Certified SysOps Administrator - Associate'},
#   {'authority': 'Amazon Web Services',
# ...

# %%
sample.keys()
# Out:
# dict_keys(['positions', 'profile'])
